# %%
GROQ_API_KEY = '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'

# %%
from groq import Groq
import base64


# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "image.jpg"

# Getting the base64 string
base64_image = encode_image(image_path)

client = Groq(
    api_key=GROQ_API_KEY
)


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": """name all the ingredients of the recipe. now give the macros values per 100gm in json format along with name as : 
                        {  name: ,
                           carbs: , 
                           proteins: , 
                           fats: 
                        }
                Just provide me the structured json and nothing else"""
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}",
                    },
                },
            ],
        }
    ],
    model="llava-v1.5-7b-4096-preview",
)

print(chat_completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[15], line 21
#      14 base64_image = encode_image(image_path)
#      16 client = Groq(
#      17     api_key=GROQ_API_KEY
#      18 )
# ---> 21 chat_completion = client.chat.completions.create(
#      22     messages=[
#      23         {
#      24             "role": "user",
#      25             "content": [
#      26                 {"type": "text", "text": """name all the ingredients of the recipe. now give the macros values per 100gm in json format along with name as :
#      27                         {  name: ,
#      28                            carbs: ,
#      29                            proteins: ,
#      30                            fats:
#      31                         }
#      32                 Just provide me the structured json and nothing else"""
#      33                 },
# ...
